# %%
# 라이브러리 다운로드
# !pip install pandas numpy matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\zkzkf\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

# %%
s_store_2025_3 = pd.read_csv(
    "C:\\Users\\zkzkf\\OneDrive\\바탕 화면\\cafe_startup_analysis\\01_area_selection\\data\\raw\\2025 3분기_소규모.csv",
    encoding="cp949"
)
# Out:
# C:\Users\zkzkf\AppData\Local\Temp\ipykernel_14060\658951686.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   s_store_2025_3 = pd.read_csv(

# %%
s_store_2025_3.shape
# Out:
# (11278, 76)

# %%
s_store_2025_3.columns
# Out:
# Index(['조사분기', '표본구분', '광역상권', '상권명', '시군구코드', '용도지역1명', '용도지역2명', '용도지구1명',
#        '용도지구2명', '이용현황_지상층수', '이용현황_지하층수', '사용승인일자', '건물구조명', '건물주용도', '건폐율',
#        '용적률', '지하철역출구', '버스정류장', '도로접면명', '옥내주차장 유무명', '옥외주차장 유무명', '승객용 승강기',
#        '대지면적', '건축연면적', '전용면적', '공용면적', '전용률', '현재임대계약면적', '공실면적', '비임대면적',
#        '특이면적', '특이면적외 기타면적', '지목명', '토지대장상 토지면적', '전환률', '조사층', '임차인사용현황구분',
#        '임차인업종대분류', '임차인업종소분류', '전용면적(호)', '공용면적(호)', '임차인별면적합계',
#        '제1월계약임대료_보증금', '제1월계약임대료_월세', '제1월계약임대료_㎡당환산임대료', '제1월시장임대료_보증금',
#        '제1월시장임대료_월세', '제1월시장임대료_㎡당환산임대료', '제1월관리비총액', '제1월관리비실비총액', '제1월공실',
#        '제2월계약임대료_보증금', '제2월계약임대료_월세', '제2월계약임대료_㎡당환산임대료', '제2월시장임대료_보증금',
#        '제2월시장임대료_월세', '제2월시장임대료_㎡당환산임대료', '제2월관리비총액', '제2월관리비실비총액', '제2월공실',
#        '제3월계약임대료_보증금', '제3월계약임대료_월세', '제3월계약임대료_㎡당환산임대료', '제3월시장임대료_보증금',
#        '제3월시장임대료_월세', '제3월시장임대료_㎡당환산임대료', '제3월관리비총액', '제3월관리비실비총액', '제3월공실',
# ...

# %%
# '조사분기' 남겨야겠지? 
# '상권명'은 어떻게 생각해야할까? 
# '이용현황_지상층수', '이용현황_지하층수' 아마 사용하지 않을까?
# 면적들... 무슨 뜻인지를 모르겠네
#

# %%
s_store_2025_3.head(2)
# Out:
#      조사분기  표본구분  광역상권 상권명  시군구코드  용도지역1명  용도지역2명  용도지구1명  용도지구2명  이용현황_지상층수  \
# 0  202503     6  1.도심  서촌  11110      14       0     200       0          1
# 1  202503     6  1.도심  서촌  11110      14       0     200       0          1
#
#    이용현황_지하층수  사용승인일자  건물구조명  건물주용도  건폐율  용적률 지하철역출구 버스정류장  도로접면명  옥내주차장 유무명  \
# 0          0       1     51      4    8    1    350   180     10          0
# 1          0       1     11      4    1    1    120   120      8          0
#
#    옥외주차장 유무명  승객용 승강기  대지면적  건축연면적  전용면적  공용면적  전용률  현재임대계약면적  공실면적  비임대면적  \
# 0          0        0     2      2     4     1   10         2     1      1
# 1          0        0     2      2     4     1    9         2     1      1
#
#    특이면적  특이면적외 기타면적  지목명  토지대장상 토지면적  전환률  조사층  임차인사용현황구분 임차인업종대분류  임차인업종소분류  \
# 0     1           1    8           2    3    1          1        I       561
# 1     1           1    8           2    3    1          1        I       561
#
# ...
