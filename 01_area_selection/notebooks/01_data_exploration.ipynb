# %%
# 라이브러리 다운로드
# !pip install pandas numpy matplotlib seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\zkzkf\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# 라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option("display.max_columns", 100)
pd.set_option("display.max_rows", 100)

# %%
from pathlib import Path

print(Path.cwd())
# Out:
# c:\Users\zkzkf\OneDrive\바탕 화면\cafe_startup_analysis\01_area_selection\notebooks

# %%
# 데이터 불러오기
from pathlib import Path

data_path = Path("../data/raw/20262Q_소규모.csv")
s_store_2026_2 = pd.read_csv(data_path, encoding="cp949")

data_path = Path("../data/raw/20262Q_중대형.csv")
b_store_2026_2 = pd.read_csv(data_path, encoding="cp949")

data_path = Path("../data/raw/20262Q_집합.csv")
g_store_2026_2 = pd.read_csv(data_path, encoding="cp949")
# Out:
# C:\Users\zkzkf\AppData\Local\Temp\ipykernel_9204\139264082.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   s_store_2026_2 = pd.read_csv(data_path, encoding="cp949")
# C:\Users\zkzkf\AppData\Local\Temp\ipykernel_9204\139264082.py:8: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   b_store_2026_2 = pd.read_csv(data_path, encoding="cp949")
# C:\Users\zkzkf\AppData\Local\Temp\ipykernel_9204\139264082.py:11: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   g_store_2026_2 = pd.read_csv(data_path, encoding="cp949")

# %%
print(s_store_2026_2.shape, b_store_2026_2.shape, g_store_2026_2.shape)
# Out:
# (11344, 76) (29733, 76) (29500, 61)

# %%
s_store_2026_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11344 entries, 0 to 11343
# Data columns (total 76 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   조사분기              11344 non-null  int64
#  1   표본구분              11344 non-null  int64
#  2   광역상권              2038 non-null   object
#  3   상권명               11344 non-null  object
#  4   시군구코드             11344 non-null  int64
#  5   용도지역1명            11344 non-null  int64
#  6   용도지역2명            11344 non-null  int64
#  7   용도지구1명            11344 non-null  int64
#  8   용도지구2명            11344 non-null  int64
#  9   이용현황_지상층수         11344 non-null  int64
#  10  이용현황_지하층수         11344 non-null  int64
#  11  사용승인일자            11344 non-null  int64
#  12  건물구조명             11344 non-null  int64
#  13  건물주용도             11344 non-null  int64
#  14  건폐율               11344 non-null  int64
#  15  용적률               11344 non-null  int64
# ...

# %%
b_store_2026_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29733 entries, 0 to 29732
# Data columns (total 76 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   조사분기              29733 non-null  int64
#  1   표본구분              29733 non-null  int64
#  2   광역상권              8765 non-null   object
#  3   상권명               29733 non-null  object
#  4   시군구코드             29733 non-null  int64
#  5   용도지역1명            29733 non-null  int64
#  6   용도지역2명            29733 non-null  int64
#  7   용도지구1명            29733 non-null  int64
#  8   용도지구2명            29733 non-null  int64
#  9   이용현황_지상층수         29733 non-null  int64
#  10  이용현황_지하층수         29733 non-null  int64
#  11  사용승인일자            29733 non-null  int64
#  12  건물구조명             29733 non-null  int64
#  13  건물주용도             29733 non-null  int64
#  14  건폐율               29733 non-null  int64
#  15  용적률               29733 non-null  int64
# ...

# %%
g_store_2026_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29500 entries, 0 to 29499
# Data columns (total 61 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   조사분기              29500 non-null  int64
#  1   광역상권              5604 non-null   object
#  2   상권명               29500 non-null  object
#  3   시군구코드             29500 non-null  int64
#  4   대지면적              29500 non-null  int64
#  5   건축면적              29500 non-null  int64
#  6   건축연면적             29500 non-null  int64
#  7   건폐율               29500 non-null  int64
#  8   용적률               29500 non-null  int64
#  9   건물구조              29500 non-null  int64
#  10  건물주용도             29500 non-null  int64
#  11  이용현황_지상층수         29500 non-null  int64
#  12  이용현황_지하층수         29500 non-null  int64
#  13  사용승인일자            29500 non-null  int64
#  14  승강기수              29500 non-null  int64
#  15  용도지역              29500 non-null  int64
# ...

# %%
display(s_store_2026_2.isna().sum(), b_store_2026_2.isna().sum(), g_store_2026_2.isna().sum())  # 세 데이터프레임 모두 광역상권에 결측치가 있다.
# Out:
# 조사분기                   0
# 표본구분                   0
# 광역상권                9306
# 상권명                    0
# 시군구코드                  0
# 용도지역1명                 0
# 용도지역2명                 0
# 용도지구1명                 0
# 용도지구2명                 0
# 이용현황_지상층수              0
# 이용현황_지하층수              0
# 사용승인일자                 0
# 건물구조명                  0
# 건물주용도                  0
# 건폐율                    0
# 용적률                    0
# 지하철역출구                 0
# 버스정류장                  0
# 도로접면명                  0
# 옥내주차장 유무명              0
# 옥외주차장 유무명              0
# 승객용 승강기                0
# 대지면적                   0
# 건축연면적                  0
# 전용면적                   0
# 공용면적                   0
# 전용률                    0
# 현재임대계약면적               0
# 공실면적                   0
# 비임대면적                  0
# 특이면적                   0
# 특이면적외 기타면적             0
# 지목명                    0
# 토지대장상 토지면적             0
# 전환률                    0
# 조사층                    0
# 임차인사용현황구분              0
# ...

# %%
s_store_2026_2.columns
# Out:
# Index(['조사분기', '표본구분', '광역상권', '상권명', '시군구코드', '용도지역1명', '용도지역2명', '용도지구1명',
#        '용도지구2명', '이용현황_지상층수', '이용현황_지하층수', '사용승인일자', '건물구조명', '건물주용도', '건폐율',
#        '용적률', '지하철역출구', '버스정류장', '도로접면명', '옥내주차장 유무명', '옥외주차장 유무명', '승객용 승강기',
#        '대지면적', '건축연면적', '전용면적', '공용면적', '전용률', '현재임대계약면적', '공실면적', '비임대면적',
#        '특이면적', '특이면적외 기타면적', '지목명', '토지대장상 토지면적', '전환률', '조사층', '임차인사용현황구분',
#        '임차인업종대분류', '임차인업종소분류', '전용면적(호)', '공용면적(호)', '임차인별면적합계',
#        '제1월계약임대료_보증금', '제1월계약임대료_월세', '제1월계약임대료_㎡당환산임대료', '제1월시장임대료_보증금',
#        '제1월시장임대료_월세', '제1월시장임대료_㎡당환산임대료', '제1월관리비총액', '제1월관리비실비총액', '제1월공실',
#        '제2월계약임대료_보증금', '제2월계약임대료_월세', '제2월계약임대료_㎡당환산임대료', '제2월시장임대료_보증금',
#        '제2월시장임대료_월세', '제2월시장임대료_㎡당환산임대료', '제2월관리비총액', '제2월관리비실비총액', '제2월공실',
#        '제3월계약임대료_보증금', '제3월계약임대료_월세', '제3월계약임대료_㎡당환산임대료', '제3월시장임대료_보증금',
#        '제3월시장임대료_월세', '제3월시장임대료_㎡당환산임대료', '제3월관리비총액', '제3월관리비실비총액', '제3월공실',
# ...

# %%
b_store_2026_2.columns
# Out:
# Index(['조사분기', '표본구분', '광역상권', '상권명', '시군구코드', '용도지역1명', '용도지역2명', '용도지구1명',
#        '용도지구2명', '이용현황_지상층수', '이용현황_지하층수', '사용승인일자', '건물구조명', '건물주용도', '건폐율',
#        '용적률', '지하철역출구', '버스정류장', '도로접면명', '옥내주차장 유무명', '옥외주차장 유무명', '승객용 승강기',
#        '대지면적', '건축연면적', '전용면적', '공용면적', '전용률', '현재임대계약면적', '공실면적', '비임대면적',
#        '특이면적', '특이면적외 기타면적', '지목명', '토지대장상 토지면적', '전환률', '조사층', '임차인사용현황구분',
#        '임차인업종대분류', '임차인업종소분류', '전용면적(호)', '공용면적(호)', '임차인별면적합계',
#        '제1월계약임대료_보증금', '제1월계약임대료_월세', '제1월계약임대료_㎡당환산임대료', '제1월시장임대료_보증금',
#        '제1월시장임대료_월세', '제1월시장임대료_㎡당환산임대료', '제1월관리비총액', '제1월관리비실비총액', '제1월공실',
#        '제2월계약임대료_보증금', '제2월계약임대료_월세', '제2월계약임대료_㎡당환산임대료', '제2월시장임대료_보증금',
#        '제2월시장임대료_월세', '제2월시장임대료_㎡당환산임대료', '제2월관리비총액', '제2월관리비실비총액', '제2월공실',
#        '제3월계약임대료_보증금', '제3월계약임대료_월세', '제3월계약임대료_㎡당환산임대료', '제3월시장임대료_보증금',
#        '제3월시장임대료_월세', '제3월시장임대료_㎡당환산임대료', '제3월관리비총액', '제3월관리비실비총액', '제3월공실',
# ...

# %%
g_store_2026_2.columns
# Out:
# Index(['조사분기', '광역상권', '상권명', '시군구코드', '대지면적', '건축면적', '건축연면적', '건폐율', '용적률',
#        '건물구조', '건물주용도', '이용현황_지상층수', '이용현황_지하층수', '사용승인일자', '승강기수', '용도지역',
#        '지하철역출구', '버스정류장', '전환률', '전통시장', '기준층', '조사층', '임차인사용현황구분', '임차인업종대분류',
#        '임차인업종소분류', '전용면적(호)', '공용면적(호)', '임차인별면적합계', '제1월계약임대료_보증금',
#        '제1월계약임대료_월세', '제1월계약임대료_㎡당환산임대료', '제1월시장임대료_보증금', '제1월시장임대료_월세',
#        '제1월시장임대료_㎡당환산임대료', '제1월관리비총액', '제1월관리비실비총액', '제1월공실', '제2월계약임대료_보증금',
#        '제2월계약임대료_월세', '제2월계약임대료_㎡당환산임대료', '제2월시장임대료_보증금', '제2월시장임대료_월세',
#        '제2월시장임대료_㎡당환산임대료', '제2월관리비총액', '제2월관리비실비총액', '제2월공실', '제3월계약임대료_보증금',
#        '제3월계약임대료_월세', '제3월계약임대료_㎡당환산임대료', '제3월시장임대료_보증금', '제3월시장임대료_월세',
#        '제3월시장임대료_㎡당환산임대료', '제3월관리비총액', '제3월관리비실비총액', '제3월공실', '현계약개시일',
#        '현계약기간', '최초계약개시일', '최종조사산정액_㎡당 단가', '기타수입_㎡당 단가', '영업경비_㎡당 단가'],
#       dtype='object')

# %%
g_store_2026_2['상권명'].unique()  # 성수/뚝섬 관련 데이터가 없다. 따라서 집합상가 데이터는 분석에서 제외한다.
# Out:
# array(['0.비상권', '강릉중부', '동해천곡', '삼척중앙시장', '속초중앙시장', '영월경찰서', '원주무실지구',
#        '원주중앙/일산', '원주혁신도시', '춘천명동', '태백중앙시장', '고양시청', '고잔신도시', '광교중앙역',
#        '광명철산', '금릉역', '김포운양역', '김포장기역', '김포한강구래', '남양주다산', '남양주별내',
#        '동백지구', '동탄2신도시', '동탄센트럴파크', '모란', '미사지구', '배곧신도시', '범계학원가', '병점역',
#        '부천역', '분당역세권', '산본역', '상록수역', '상중동', '상현역', '서판교', '선부다이아몬드',
#        '성남구시가지', '송내역', '수원역', '시흥시립도서관', '안산중앙역', '안성 서인사거리', '안양역',
#        '야탑역', '역곡역', '오산시청', '용인수지', '월피다이아몬드', '위례신도시', '의정부민락', '의정부역',
#        '이천종합터미널', '인계동', '일산라페스타', '죽전카페거리', '탄현역', '파주시청', '파주야당역',
#        '파주운정호수', '팔달문로터리', '평촌범계', '평택역', '한대앞역', '행신역', '화정역', '거제고현',
#        '거제옥포', '김해수리공원', '김해시 내외동', '김해시청/동상시장', '김해장유', '마산동서동',
#        '마산역버스터미널', '물금지구', '양산구도심', '양산역', '진주혁신도시', '진해석동', '창원명곡동',
#        '창원시청', '창원역', '창원월영동', '창원의창구청', '활천동', '경북김천혁신도시', '경북도청신도시',
#        '구미산업단지', '구미역', '문경점촌흥덕', '안동구도심', '영주중앙', '옥동사거리', '포항원도심',
# ...

# %%
n_columns =  ['광역상권', '상권명', '임차인업종대분류', '임차인업종소분류', '전용면적', '전용면적(호)', '임차인별면적합계', '조사층', '건물주용도', '표본구분', '건물구조명','제3월계약임대료_보증금','제3월계약임대료_월세','제3월시장임대료_보증금','제3월시장임대료_월세', '제3월관리비실비총액']

s_store_2026_2 = s_store_2026_2[n_columns]
b_store_2026_2 = b_store_2026_2[n_columns]

# %%
s_store_2026_2 = s_store_2026_2[s_store_2026_2['상권명'] == '뚝섬']
b_store_2026_2 = b_store_2026_2[b_store_2026_2['상권명'] == '뚝섬']

# %%
display(s_store_2026_2.head(2), b_store_2026_2.head(2))
# Out:
#      광역상권 상권명 임차인업종대분류  임차인업종소분류  전용면적  전용면적(호)  임차인별면적합계  조사층  건물주용도  표본구분  \
# 653  4.기타  뚝섬        I       561     2        2         2    1      4     6
# 654  4.기타  뚝섬        I       562     4        2         2   -1      4     6
#
#      건물구조명  제3월계약임대료_보증금  제3월계약임대료_월세  제3월시장임대료_보증금  제3월시장임대료_월세  제3월관리비실비총액
# 653     12             6            6             6            6           1
# 654     11             5            5             5            5           1
#       광역상권 상권명 임차인업종대분류  임차인업종소분류  전용면적  전용면적(호)  임차인별면적합계  조사층  건물주용도  표본구분  \
# 1731  4.기타  뚝섬        G       478     5        4         4   -1      3     2
# 1732  4.기타  뚝섬        I       561     5        2         2    1      3     2
#
#       건물구조명  제3월계약임대료_보증금  제3월계약임대료_월세  제3월시장임대료_보증금  제3월시장임대료_월세  제3월관리비실비총액
# 1731     21             4            4             6            5           1
# 1732     21             6            6             6            6           1

# %%
print(s_store_2026_2.shape, b_store_2026_2.shape)
# Out:
# (64, 16) (215, 16)
